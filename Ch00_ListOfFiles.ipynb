# %% [markdown]
# # List of Files

# %%
using Printf
include("src/printmat.jl");

# %%
files = filter(x -> endswith(lowercase(x),".ipynb"), readdir())  #all .ipynb files
filter!(x -> x != "Ch00_ListOfFiles.ipynb",files)

printmat(files)
# Out:
# Ch00_HowToUse.ipynb
# Ch01_StatsReview.ipynb
# Ch02a_OLS.ipynb
# Ch02b_Diagnostics.ipynb
# Ch02c_FrischWaugh.ipynb
# Ch03_Betas.ipynb
# Ch04a_OLS_Testing.ipynb
# Ch04b_DeltaMethod.ipynb
# Ch05_OLS_non_iid.ipynb
# Ch06_OLS_System.ipynb
# Ch08a_ModelSelection.ipynb
# Ch08b_OLS_Lasso.ipynb
# Ch09_Asymptotics.ipynb
# Ch10a_MonteCarlo.ipynb
# Ch10b_Bootstrap.ipynb
# Ch11_PortfolioSorts.ipynb
# Ch12_PanelRegr.ipynb
# Ch13_IV.ipynb
# Ch14_GMM.ipynb
# Ch15a_TimeSeries_AR.ipynb
# Ch15b_TimeSeries_MA.ipynb
# Ch18_Distributions.ipynb
# Ch19_MLE.ipynb
# Ch20a_Garch.ipynb
# Ch20b_DCC.ipynb
# Ch22_NonparametricRegression.ipynb
# Ch23_QuantileRegression.ipynb
# Ch24_BinaryChoice.ipynb
